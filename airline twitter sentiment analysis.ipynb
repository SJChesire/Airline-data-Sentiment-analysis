# %%
import numpy as np
import pandas as pd

import os

for dirname, _, filenames in os.walk('C:\\Users\\HP 840\\Desktop\\Airline sentiment analysis'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\HP 840\Desktop\Airline sentiment analysis\airline twitter sentiment analysis.ipynb
# C:\Users\HP 840\Desktop\Airline sentiment analysis\Tweets.csv
# C:\Users\HP 840\Desktop\Airline sentiment analysis\.ipynb_checkpoints\airline twitter sentiment analysis-checkpoint.ipynb

# %%
import matplotlib.pyplot as plt

# %%
dff = pd.read_csv("C:\\Users\\HP 840\\Desktop\\Airline sentiment analysis\\Tweets.csv")

# %%
dff.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
dff.shape
# Out:
# (14640, 15)

# %%
df = dff.loc[:,['airline_sentiment','text']]

# %%
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df['airline_sentiment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='airline_sentiment'>

# %%
import matplotlib.pyplot as plt
colors = {'negative': '#FF6F61', 'neutral': '#6B5B95', 'positive': '#88B04B'}
sentiment_counts = df['airline_sentiment'].value_counts()
plt.figure(figsize=(10, 6))
bars = plt.bar(sentiment_counts.index, sentiment_counts.values, color=[colors[sentiment] for sentiment in sentiment_counts.index])
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom', ha='center', fontsize=12, fontweight='bold')
plt.title('Distribution of Airline Sentiment', fontsize=16, fontweight='bold')
plt.xlabel('Sentiment', fontsize=14)
plt.ylabel('Number of Tweets', fontsize=14)

plt.show()

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
stem = PorterStemmer()

# %%
uni = dff['airline'].unique()
uni = [x.split() for x in uni]
uni = ["".join(x) for x in uni]
uni = [x.lower() for x in uni]

# %%
def func(x):
    x = re.sub("[^a-zA-Z]"," ",x)
    x = x.split()
    x = [i.strip() for i in x]
    x = [stem.stem(i) for i in x if (i not in set(stopwords.words('english')) or i not in uni)]
    return " ".join(x)

# %%
df['text'] = df['text'].apply(func)

# %%
mm = df['text'].head(1000)

# %%
from wordcloud import WordCloud
text = ' '.join(mm)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
model = TfidfVectorizer(max_features=1000)

# %%
text = model.fit_transform(df['text'])

# %%
array = text.toarray()

# %%
from sklearn.model_selection import train_test_split
x_tr,x_te,y_tr,y_te = train_test_split(array,df['airline_sentiment'])

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=9)

# %%
model.fit(x_tr,y_tr)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
preds = model.predict(x_te)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_te,preds)
# Out:
# 0.7368852459016394
